# %% [markdown]
# <a href="https://colab.research.google.com/github/diegonogare/GoogleColab/blob/main/numpy_imagem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# $$ y(t) = e^{-t} $$
# $$ y(t) = e^{-t} cos(2 \pi t) $$
# $$ y(t) = e^{-|t|} sin(t) $$

# %%
np.random.seed(42)
r = np.random.rand(1,10000,1)

plt.figure(figsize=(15,8))

plt.scatter(r, np.e**-r, color="tab:cyan", s=10, marker='^')
plt.scatter(r, np.e**-r * np.cos(2 * np.pi * r), color="tab:purple", s=10)
plt.scatter(r, np.e**-np.abs(r) * np.sin(r), color="tab:green", s=10);

# %%
print(np.e)
# Out:
# 2.718281828459045

# %%
from skimage import io
import numpy as np
import matplotlib.pyplot as plt

# %%
onibusEspacial = io.imread("https://images-na.ssl-images-amazon.com/images/I/4177FO4w94L._SX466_.jpg")
print(onibusEspacial.shape)

plt.imshow(onibusEspacial);
# Out:
# (297, 466, 3)

# %%
recorte = onibusEspacial[150:200,150:200,]
print(recorte.shape)

recorte[0:10,0:10,0] = 15 #R
recorte[0:10,0:10,1] = 15 #G
recorte[0:10,0:10,2] = 15 #B
plt.imshow( recorte )

#print( recorte)
# Out:
# (50, 50, 3)

# %%
print( onibusEspacial[150:200,150:200,] )
# Out:
# [[[173 173 171]
#   [173 173 171]
#   [171 171 169]
#   ...
#   [162 164 163]
#   [169 171 170]
#   [178 180 179]]
#
#  [[176 176 174]
#   [171 171 169]
#   [170 170 168]
#   ...
#   [160 162 161]
#   [166 168 167]
#   [174 176 175]]
#
#  [[165 165 163]
#   [176 176 174]
#   [171 171 169]
#   ...
#   [161 163 162]
#   [172 174 173]
#   [176 178 177]]
#
#  ...
#
#  [[169 169 167]
#   [170 170 168]
#   [177 177 175]
#   ...
#   [184 184 186]
#   [183 183 185]
#   [182 182 184]]
#
#  [[175 175 173]
#   [176 176 174]
#   [181 181 179]
#   ...
#   [179 179 181]
#   [179 179 181]
#   [180 180 182]]
#
#  [[178 178 176]
#   [179 179 177]
#   [182 182 180]
#   ...
#   [178 178 178]
#   [179 179 179]
#   [181 181 181]]]

# %%
print(onibusEspacial[:,:,:])

recorte = onibusEspacial[150:200, 150:200, ]
plt.imshow(recorte) # Exibição da imagem
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
recorte = onibusEspacial[170:180, 170:180, ]

plt.imshow(recorte[0:1,:,:]) # Exibição da imagem
print(recorte[0:1,:,:])
# Out:
# [[[ 25  49  49]
#   [ 30  51  54]
#   [ 52  71  75]
#   [ 36  51  56]
#   [ 45  58  64]
#   [ 44  55  61]
#   [ 25   0   0]
#   [115  71  70]
#   [141  85  84]
#   [158  88  90]]]

# %%
onibusEspacial = io.imread("https://www.nasa.gov/sites/default/files/styles/image_card_4x3_ratio/public/thumbnails/image/iss016e032596_orig.jpg")
print(onibusEspacial.shape)

plt.imshow(onibusEspacial);
# Out:
# (300, 400, 3)

# %%
#print(onibusEspacial[:,:,:])

recorte = onibusEspacial[180:220, 270:300, ]
plt.imshow(recorte) # Exibição da imagem

# %%
from skimage.color import rgb2gray

original = onibusEspacial
grayscale = rgb2gray(original)

plt.imshow(grayscale, cmap=plt.cm.gray)

# %%
#R G B
onibusEspacial_vermelho = onibusEspacial.copy()
#onibusEspacial_vermelho[:,:,0] = 0 #Red
onibusEspacial_vermelho[:,:,1] = 0 #Green
onibusEspacial_vermelho[:,:,2] = 0 #Blue

plt.imshow(onibusEspacial_vermelho)

# %%
#R G B
onibusEspacial_verde = onibusEspacial.copy()
onibusEspacial_verde[:,:,0] = 0 #R 
#onibusEspacial_verde[:,:,1] = 0 #G
onibusEspacial_verde[:,:,2] = 0 #B

plt.imshow(onibusEspacial_verde)

# %%
#R G B
onibusEspacial_azul = onibusEspacial.copy()
onibusEspacial_azul[:,:,0] = 0 #R 
onibusEspacial_azul[:,:,1] = 0 #G
#onibusEspacial_azul[:,:,2] = 0 #B

plt.imshow(onibusEspacial_azul)

# %%
plt.figure(figsize=(15,8))

img = io.imread('http://diegonogare.net/wp-content/uploads/2020/07/mentoria_DiegoNogare.jpg') # Carregamento da imagem
print(img.shape)

plt.imshow(img);
# Out:
# (600, 600, 3)

# %%
plt.figure(figsize=(15,8))

Topo = 357 #Top
Esquerda = 394 #Left
Largura = 85 # width
altura = 85 # height

nova_img = img[357:357+85, 394:394+85]
plt.imshow(nova_img) # Exibição da imagem
